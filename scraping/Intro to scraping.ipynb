# %% [markdown]
# # Screen Scraping
#
# -
#
# ### César de Pablo Sánchez

# %% [markdown]
# ## Conceptos generales de scraping

# %% [markdown]
# ## Ejemplo de scraping con _lxml_ y _requests_

# %% [markdown]
# ### Descripción de requests

# %% [markdown]
# ### Descripción de lxml

# %% [markdown]
# ### Ejemplo - _Scrapear_ cursos desde la página de Cloudera

# %% [markdown]
# ### 0. [Listado de cursos de artes y humanidades]('https://www.coursera.org/browse/arts-and-humanities')

# %% [markdown]
# ###  1. Descargar página

# %%
import requests
from lxml import etree
from io import StringIO, BytesIO

parser = etree.HTMLParser() 

r = requests.get('https://www.coursera.org/browse/arts-and-humanities')

# %%
r.text
# Out:
# u'<!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org"><head><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta name="fragment" content="!"><meta name="robots" content="NOODP"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="prerender-status-code" content="503"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="apple-touch-icon" sizes="57x57" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-57x57.png"><link rel="apple-touch-icon" sizes="60x60" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-60x60.png"><link rel="apple-touch-icon" sizes="72x72" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-72x72.png"><link rel="apple-touch-icon" sizes="76x76" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-76x76.png"><link rel="apple-touch-icon" sizes="114x114" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-114x114.png"><link rel="apple-touch-icon" sizes="120x120" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-120x120.png"><link rel="apple-touch-icon" sizes="144x144" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-144x144.png"><link rel="apple-touch-icon" sizes="152x152" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-152x152.png"><link rel="apple-touch-icon" sizes="180x180" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-180x180.png"><link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-194x194.png" sizes="194x194"><link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/android-chrome-192x192.png" sizes="192x192"><link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-blue-96x96.png" sizes="96x96"><link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-blue-16x16.png" sizes="16x16"><link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-blue-32x32.png" sizes="32x32"><meta name="msapplication-TileColor" content="#2d89ef"><meta name="msapplication-TileImage" content="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/mstile-144x144.png"><meta name="theme-color" content="#4689c6"><meta property="og:title" content="Coursera - Free Online Courses From Top Universities"><meta property="og:locale" content="en_US"><meta property="og:type" content="website"><meta name="description" content="Take free online classes from 120+ top universities and educational organizations. We partner with schools like Stanford, Yale, Princeton, and others to offer courses in dozens of topics, from computer science to teaching and beyond. Whether you are pursuing a passion or looking to advance your career, Coursera provides open, free education for everyone."><meta property="og:description" content="Take free online classes from 120+ top universities and educational organizations. We partner with schools like Stanford, Yale, Princeton, and others to offer courses in dozens of topics, from computer science to teaching and beyond. Whether you are pursuing a passion or looking to advance your career, Coursera provides open, free education fo ...

# %%
tree   = etree.parse(StringIO(r.text), parser)
result = etree.tostring(tree.getroot(), pretty_print=True,  method = 'html')
print(result)
# Out:
# <html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7">
# <meta name="fragment" content="!">
# <meta name="robots" content="NOODP">
# <meta charset="utf-8">
# <meta property="og:site_name" content="Coursera">
# <meta property="fb:admins" content="727836538,4807654">
# <meta property="fb:app_id" content="823425307723964">
# <meta name="twitter:site" content="Coursera">
# <meta name="twitter:app:name:iphone" content="Coursera">
# <meta name="twitter:app:name:ipad" content="Coursera">
# <meta name="twitter:app:name:googleplay" content="Coursera">
# <meta name="twitter:app:id:iphone" content="id736535961">
# <meta name="twitter:app:id:ipad" content="id736535961">
# <meta name="twitter:app:id:googleplay" content="org.coursera.android">
# <meta name="prerender-status-code" content="503">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="apple-touch-icon" sizes="57x57" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-57x57.png">
# <link rel="apple-touch-icon" sizes="60x60" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-60x60.png">
# <link rel="apple-touch-icon" sizes="72x72" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-72x72.png">
# <link rel="apple-touch-icon" sizes="76x76" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-76x76.png">
# <link rel="apple-touch-icon" sizes="114x114" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-114x114.png">
# <link rel="apple-touch-icon" sizes="120x120" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-120x120.png">
# <link rel="apple-touch-icon" sizes="144x144" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-144x144.png">
# <link rel="apple-touch-icon" sizes="152x152" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-152x152.png">
# <link rel="apple-touch-icon" sizes="180x180" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-180x180.png">
# <link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-194x194.png" sizes="194x194">
# <link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/android-chrome-192x192.png" sizes="192x192">
# <link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-blue-96x96.png" sizes="96x96">
# <link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-blue-16x16.png" sizes="16x16">
# <link rel="icon" type="image/png" href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/icon-blue-32x32.png" sizes="32x32">
# <meta name="msapplication-TileColor" content="#2d89ef">
# <meta name="msapplication-TileImage" content="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/mstile-144x144.png">
# <meta name="theme-color" content="#4689c6">
# <meta property="og:title" content="Coursera - Free Online Courses From Top Universities">
# <meta property="og:locale" content="en_US">
# <meta property="og:type" content="website">
# <meta name="description" content="Take free online classes from 120+ top universities and educational organizations. We partner with schools like Stanford, Yale, Princeton, and others to offer courses in dozens of topics, from computer science to teaching and beyond. Whether you are pursuing a passion or looking to advance your career, Coursera provides open, free education for everyone.">
# <meta property="og:description" content="Take free online classes from 120+ top universities and educational organizations. We partner with schools like Stanford, Yale, Princeton, and others to offer courses in dozens of topics, from computer science to teaching and beyond. Whether you are pursuing a passion or looking to advance your career, Coursera provides open, free education for everyone.">
# <meta name="image" content="http://s3.amazonaws.com/coursera/media/Coursera_Computer_Narrow.png">
# <meta property="og:image" content="http://s3.amazonaws.com/coursera/media/Coursera_Computer_Narrow.png">
# <meta property="og:url" content="https://www.coursera.org/browse/arts-and-humanities">
# <meta property="qc:admins" content="366737676376375235216727">
# <script>// NOTE: This file gets included in Jade pre-transformed so it must be ES5-safe.
#
# // we need to import this into our base HTML file as well as our main app scripts
# // so we need to support a window global && (common || amd) imports
# (function(global, factory) {
#   if (typeof exports === 'object' && typeof module != 'undefined') {
#     module.exports = factory();
#   } else if (typeof define === 'function' && define.amd) {
#     define(factory);
#   } else {
#     global.errorTracker = factory();
#   }
# }(this, function() {
#
#   var lastError = {};
#
#   function errorEquals(left, right) {
#     return ['message', 'url', 'line', 'column'].every(function(field) {
#       return left[field] == right[field];
#     });
#   }
#
#   return function(tracker, options) {
#     options = options || {};
#
#     var logger = options.logger || (window && window.console) || {error: function() {}};
#     var version = options.version || '';
#
#     var stringifyError = function(error) {
#       var plainObject = {};
#       if (error && typeof(error) == 'object') {
#         Object.getOwnPropertyNames(error).forEach(function(key) {
#           plainObject[key] = error[key];
#         });
#       }
#       return JSON.stringify(plainObject);
#     };
#
#     var logClientSideError = function(message, url, line, column, error) {
#       // errors without line numbers aren't helpful, chuck them
#       if (line === undefined || line == null || !url) return;
#
#       if (message.target && message.type) {
#         message = message.type;
#       }
#
#       if (error && error.stack) {
#         var findStackUrlRegExp = /\(([^)\s]+?):\d+:\d+\)/gm;
#         var findLastStackUrlRegExp = /\s*(https?:\/\/[^:\s]+?):\d+:\d+\s*$/gm;
#         var match;
#         var local = true;
#
#         // test for parens enclosed URLs in stack trace
#         while (match = findStackUrlRegExp.exec(error.stack)) {
#           if (match && !options.scriptFilter.test(match[1])) {
#             local = false;
#             break;
#           }
#         }
#
#         // test for last URL in stack trace
#         if (local) {
#           while (match = findLastStackUrlRegExp.exec(error.stack)) {
#             if (match && !options.scriptFilter.test(match[1])) {
#               local = false;
#               break;
#             }
#           }
#         }
#
#         // if stack trace shows us external scripts are buggy, don't log
#         if (!local) return;
#       }
#
#       var errorStr = stringifyError(error);
#       var errorDescrip = {
#         message: message,
#         script: url,
#         line: line,
#         url: window && window.document ? window.document.URL : url,
#         column: column,
#         error: errorStr,
#         version: version,
#       };
#
#       logger.error(errorStr);
#
#       var trackableUrl = url && (!options.scriptFilter || options.scriptFilter.test(url));
#
#       if (trackableUrl) {
#         var isNewError = !errorEquals(errorDescrip, lastError);
#
#         // don't track the same error over and over again
#         if (isNewError) {
#           lastError = errorDescrip;
#           tracker(errorDescrip);
#         }
#       }
#     };
#
#     if (typeof window !== 'undefined') {
#       window.onerror = logClientSideError;
#       if (window.errorTracker) {
#         delete window.errorTracker;
#       }
#     } else {
#       return logClientSideError;
#     }
#   };
# }));
# window._204 = [];
# window._400 = [];
# if(window.errorTracker) {
#   window.errorTracker(
#     function(error) {
#       window._204.push({key:'page.error.javascript', value:error});
#     },
#     {
#       scriptFilter: new RegExp('^/|^' + location.protocol + '//' + location.host + '|^https://d3njjcbhbojbot.cloudfront.net/web/'),
#       version:"2640a618f0be8f7b58032f8d972ecf7662320cd8",
#     });
# }</script><style>@font-face {
#   font-family: 'coursera-iconfont';
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v11.eot");
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v11.eot?#iefix") format('embedded-opentype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v11.woff") format('woff'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v11.ttf") format('truetype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v11.svg") format('svg');
# }
#
# @font-face {
#   font-family: 'sofiapro';
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproregular.eot");
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproregular.eot?#iefix") format('embedded-opentype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproregular.woff2") format('woff2'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproregular.woff") format('woff'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproregular.ttf") format('truetype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproregular.svg#sofiapro") format('svg');
#   font-weight: normal;
#   font-style: normal;
# }
#
# @font-face {
#   font-family: 'sofiapro-bold';
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprobold.eot");
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprobold.eot?#iefix") format('embedded-opentype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprobold.woff2") format('woff2'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprobold.woff") format('woff'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprobold.ttf") format('truetype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprobold.svg#sofiapro-bold") format('svg');
#   font-weight: normal;
#   font-style: normal;
# }
#
# @font-face {
#   font-family: 'sofiapro-light';
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprolight.eot");
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprolight.eot?#iefix") format('embedded-opentype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprolight.woff2") format('woff2'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprolight.woff") format('woff'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprolight.ttf") format('truetype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaprolight.svg#sofiapro-light") format('svg');
#   font-weight: normal;
#   font-style: normal;
# }
#
# @font-face {
#   font-family: 'sofiapro-extralight';
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproextralight.eot");
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproextralight.eot?#iefix") format('embedded-opentype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproextralight.woff2") format('woff2'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproextralight.woff") format('woff'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproextralight.ttf") format('truetype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiaproextralight.svg#sofiapro-extralight") format('svg');
#   font-weight: normal;
#   font-style: normal;
# }
#
# @font-face {
#   font-family: 'sofiapro-medium';
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiapromedium.eot");
#   src: url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiapromedium.eot?#iefix") format('embedded-opentype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiapromedium.woff2") format('woff2'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiapromedium.woff") format('woff'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiapromedium.ttf") format('truetype'),
#        url("https://d3njjcbhbojbot.cloudfront.net/web/type/sofiapro/sofiapromedium.svg#sofiapro-medium") format('svg');
#   font-weight: normal;
#   font-style: normal;
# }</style>
# <link href="https://d3njjcbhbojbot.cloudfront.net/web/2640a618f0be8f7b58032f8d972ecf7662320cd8/pages/catalog/styl/all.css" rel="stylesheet" type="text/css">
# <title>Coursera - Free Online Courses From Top Universities</title>
# <meta name="prerender-status-code" content="503">
# <link rel="alternate" hreflang="en" href="https://en.coursera.org/">
# <link rel="alternate" hreflang="es" href="https://es.coursera.org/">
# <link rel="alternate" hreflang="fr" href="https://fr.coursera.org/">
# <link rel="alternate" hreflang="pt" href="https://pt.coursera.org/">
# <link rel="alternate" hreflang="ru" href="https://ru.coursera.org/">
# <link rel="alternate" hreflang="tr" href="https://tr.coursera.org/">
# <link rel="alternate" hreflang="zh" href="https://zh.coursera.org/">
# <link rel="alternate" hreflang="zh-tw" href="https://zh-tw.coursera.org/">
# <link rel="alternate" hreflang="en" href="https://www.coursera.org/">
# <link rel="alternate" hreflang="x-default" href="https://www.coursera.org/">
# </head>
# <body>
# <div id="fb-root"></div>
# <div id="rendered-content"><div class="rc-CatalogApplication" data-reactid=".27o3oqaqeww" data-react-checksum="-1134476935">
# <div data-reactid=".27o3oqaqeww.0">
# <div class="rc-PageHeader" data-reactid=".27o3oqaqeww.0.0"><nav class="bt3-navbar c-ph-nav" role="navigation" data-reactid=".27o3oqaqeww.0.0.0"><div class="bt3-container-fluid c-container" data-reactid=".27o3oqaqeww.0.0.0.0">
# <div class="c-ph-logo bt3-navbar-header" data-reactid=".27o3oqaqeww.0.0.0.0.0">
# <div class="c-ph-mobile-toggle-button" data-reactid=".27o3oqaqeww.0.0.0.0.0.0"><button class="bt3-navbar-toggle c-collapsed-toggle-button" data-toggle="collapse" data-target="#c-ph-right-nav" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0"><span class="bt3-sr-only" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0.0">Toggle navigation</span><span class="c-hidden-accessibility" data-js="navbar-toggle-open" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0.1">Navigation open</span><span class="c-hidden-accessibility" data-js="navbar-toggle-closed" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0.2">Navigation closed</span><span class="bt3-icon-bar" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0.3"></span><span class="bt3-icon-bar" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0.4"></span><span class="bt3-icon-bar" data-reactid=".27o3oqaqeww.0.0.0.0.0.0.0.5"></span></button></div>
# <a href="/" class="c-logo" data-reactid=".27o3oqaqeww.0.0.0.0.0.1"><img src="data:image/svg+xml;base64,..." class="rc-CourseraLogo" alt="Coursera" data-reactid=".27o3oqaqeww.0.0.0.0.0.1.0"></a>
# </div>
# <div class="c-ph-search-bar bt3-navbar-header c-center-search-input c-has-catalog-button" data-reactid=".27o3oqaqeww.0.0.0.0.1"><span class="c-ph-search-wrapper" data-reactid=".27o3oqaqeww.0.0.0.0.1.0"><a class="c-catalog-button active" href="/browse/" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.0"><i class="cif-course-list c-catalog-icon" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.0.0"></i><span data-reactid=".27o3oqaqeww.0.0.0.0.1.0.0.1">Catalog</span></a><form class="c-search-form" action="/courses" method="GET" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.1"><span class="c-search-input-container" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.1.0"><input type="text" class="c-search-catalog-input " placeholder="Search catalog" value="" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.1.0.0"><a data-reactid=".27o3oqaqeww.0.0.0.0.1.0.1.0.1"><i class="cif-search c-search-icon" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.1.0.1.0"><input type="submit" class="c-search-submit" value="" data-reactid=".27o3oqaqeww.0.0.0.0.1.0.1.0.1.0.0"></i></a></span></form></span></div>
# <div id="c-ph-right-nav" class="c-ph-right-nav collapse" data-reactid=".27o3oqaqeww.0.0.0.0.2"><ul class="c-navbar-list bt3-nav bt3-navbar-nav bt3-navbar-right" data-reactid=".27o3oqaqeww.0.0.0.0.2.0">
# <li class="c-ph-right-nav-button" data-reactid=".27o3oqaqeww.0.0.0.0.2.0.0:$Institutions"><a href="/partners" data-popup-close="true" data-reactid=".27o3oqaqeww.0.0.0.0.2.0.0:$Institutions.0">Institutions</a></li>
# <li class="c-ph-right-nav-button" data-reactid=".27o3oqaqeww.0.0.0.0.2.0.1"><a data-click-key="page.header.click.login" href="/browse/arts-and-humanities?authMode=login" class=" active" data-reactid=".27o3oqaqeww.0.0.0.0.2.0.1.0">Log In</a></li>
# <li class="c-ph-right-nav-button" data-reactid=".27o3oqaqeww.0.0.0.0.2.0.2"><a data-click-key="page.header.click.signup" href="/browse/arts-and-humanities?authMode=signup" class="bt3-btn bt3-btn-primary active" data-reactid=".27o3oqaqeww.0.0.0.0.2.0.2.0">Sign Up</a></li>
# </ul></div>
# </div></nav></div>
# <noscript data-reactid=".27o3oqaqeww.0.1"></noscript>
# <noscript data-reactid=".27o3oqaqeww.0.2"></noscript>
# </div>
# <div class="rc-DomainPage" data-reactid=".27o3oqaqeww.1"><div class="rc-BrowseLayout" data-reactid=".27o3oqaqeww.1.0">
# <div class="cover-photo-container tile" style="background-image:url(https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera_assets.s3.amazonaws.com/growth_discovery/images/domains/arts-and-humanities.r1.png?auto=&amp;dpr=1);" data-reactid=".27o3oqaqeww.1.0.0"></div>
# <div class="bt3-container" data-reactid=".27o3oqaqeww.1.0.1"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0">
# <div class="bt3-col-sm-9 bt3-col-sm-push-3 main-container" data-reactid=".27o3oqaqeww.1.0.1.0.0">
# <div class="rc-BrowseBreadcrumbs" data-reactid=".27o3oqaqeww.1.0.1.0.0.0">
# <a class="catalog-browse-link active" href="/browse/" data-reactid=".27o3oqaqeww.1.0.1.0.0.0.0">Catalog</a><i class="cif-chevron-right" data-reactid=".27o3oqaqeww.1.0.1.0.0.0.1"></i><a class="catalog-browse-link active" href="/browse/arts-and-humanities" data-reactid=".27o3oqaqeww.1.0.1.0.0.0.$arts-and-humanities">Arts and Humanities</a>
# </div>
# <div class="browse-summary" data-reactid=".27o3oqaqeww.1.0.1.0.0.1">
# <h1 data-reactid=".27o3oqaqeww.1.0.1.0.0.1.0">Arts and Humanities</h1>
# <p data-reactid=".27o3oqaqeww.1.0.1.0.0.1.1">Specializations and courses in the arts and humanities (including fine arts, history, and philosophy) explore the historical context of creative works and teach you to review source material critically, draw connections between diverse ideas, and evaluate evidence and arguments. Coursework in this field will help you become a better reader, thinker, artist, and writer.</p>
# </div>
# <div class="rc-BrowseFiltersContainer" data-reactid=".27o3oqaqeww.1.0.1.0.0.2">
# <span class="c-fb-active-filters bt3-col-xs-10" data-reactid=".27o3oqaqeww.1.0.1.0.0.2.1"><span class="c-fb-active-filters-text" data-reactid=".27o3oqaqeww.1.0.1.0.0.2.1.0">Active Filters:</span></span><span class="bt3-col-xs-2 bt3-text-right" data-reactid=".27o3oqaqeww.1.0.1.0.0.2.2"><button class="c-fb-filter-modal-button" data-reactid=".27o3oqaqeww.1.0.1.0.0.2.2.0"><img class="c-fb-filter-modal-button-img" src="https://d3njjcbhbojbot.cloudfront.net/web/bundles/catalog-browse/images/filter-modal-button.svg" data-reactid=".27o3oqaqeww.1.0.1.0.0.2.2.0.0"></button></span>
# </div>
# <div data-reactid=".27o3oqaqeww.1.0.1.0.0.3">
# <div class="rc-SubdomainsIndex" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0">
# <span class="index-item" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$history"><a href="#history" class="index-item-link" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$history.0">History</a><span class="index-item-delimiter" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$history.1">|</span></span><span class="index-item" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$language-and-literature"><a href="#language-and-literature" class="index-item-link" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$language-and-literature.0">Language and Literature</a><span class="index-item-delimiter" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$language-and-literature.1">|</span></span><span class="index-item" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$music-and-art"><a href="#music-and-art" class="index-item-link" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$music-and-art.0">Music and Art</a><span class="index-item-delimiter" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$music-and-art.1">|</span></span><span class="index-item" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$philosophy"><a href="#philosophy" class="index-item-link" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$philosophy.0">Philosophy</a><span class="index-item-delimiter" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.0.$philosophy.1">|</span></span>
# </div>
# <div class="rc-SubdomainSampler" id="history" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.0">History</h2>
# <div data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1">
# <div data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0">
# <a data-click-key="catalog.click.offering_card" href="/learn/buddhist-meditation" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/88/dca9404aca11e5ab88a912c019e599/buddha.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/88/dca9404aca11e5ab88a912c019e599/buddha.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/88/dca9404aca11e5ab88a912c019e599/buddha.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.1.0.0">Tibetan Buddhist Meditation and the Modern World: Lesser Vehicle</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$aaNxjzc9EeWO-Qq6rEZAow.0.0.1.0.1.0">University of Virginia</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/course/romanarchitecture" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/d8/96bb86b6f727c154bb07d83cf2674c/deek_courselogo.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/d8/96bb86b6f727c154bb07d83cf2674c/deek_courselogo.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/d8/96bb86b6f727c154bb07d83cf2674c/deek_courselogo.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0.0">Roman Architecture</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0.1.0">Yale University</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/learn/modern-world" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/53/8222e51c172488b83cb9b707f35145/Flag-Globe.png?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/53/8222e51c172488b83cb9b707f35145/Flag-Globe.png?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/53/8222e51c172488b83cb9b707f35145/Flag-Globe.png?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.1.0.0">The Modern World, Part One: Global History from 1760 to 1910</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$3UY0FCmGEeWFggqB2SRvtQ.0.0.1.0.1.0">University of Virginia</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/learn/ancient-greeks" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/36/feeefc3aabeeca9639b583f0a6b2f2/ancientgreek.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/36/feeefc3aabeeca9639b583f0a6b2f2/ancientgreek.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/36/feeefc3aabeeca9639b583f0a6b2f2/ancientgreek.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.1.0.0">The Ancient Greeks</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$zTzjmvssEeSDoyIAC1CH0g.0.0.1.0.1.0">Wesleyan University</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/course/ancientegypt" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/80/223800efdb11e498484f2a04afd83d/egypt.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/80/223800efdb11e498484f2a04afd83d/egypt.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/80/223800efdb11e498484f2a04afd83d/egypt.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.1.0.0">Ancient Egypt: A history in six objects</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-3077.0.0.1.0.1.0">University of Manchester</span></div>
# </div></div>
# </div></div></a>
# </div>
# <div class="bt3-text-center" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.1"><a class="" href="/browse/arts-and-humanities/history" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.1.0"><button class="primary see-all-button" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.1.0.0">See All</button></a></div>
# </div>
# </div>
# <div class="rc-SubdomainSampler" id="language-and-literature" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.0">Language and Literature</h2>
# <div data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1">
# <div data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0">
# <a data-click-key="catalog.click.offering_card" href="/specializations/academic-english" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d396qusza40orc.cloudfront.net/phoenixassets/academic-english-s12n/academic-english%20%281%29.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d396qusza40orc.cloudfront.net/phoenixassets/academic-english-s12n/academic-english%20%281%29.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d396qusza40orc.cloudfront.net/phoenixassets/academic-english-s12n/academic-english%20%281%29.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.0">Academic English: Writing</h2>
# <div data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.1">
# <span class="specialization-course-count" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.1.0"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.1.0.0">5-course Specialization</span></span><span class="dot-delimiter" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.1.1">&#194;&#183;</span><span class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.1.2"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$_DKB-EeMEeWpwg5iaKtymQ.0.0.1.0.1.2.0">University of California, Irvine</span></span>
# </div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/learn/grammar-punctuation" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/67/d4fe7008ab11e5bafdef7a396556ec/grammar.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/67/d4fe7008ab11e5bafdef7a396556ec/grammar.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/67/d4fe7008ab11e5bafdef7a396556ec/grammar.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.1.0.0">Grammar and Punctuation</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$CQk7JA46EeWuEBJhzy2uFw.0.0.1.0.1.0">University of California, Irvine</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/course/basicwriting" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bd/c650a4feea8765e09f7045f205649b/msjc.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bd/c650a4feea8765e09f7045f205649b/msjc.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bd/c650a4feea8765e09f7045f205649b/msjc.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.1.0.0">Crafting an Effective Writer: Tools of the Trade (Fundamental English Writing)</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-469.0.0.1.0.1.0">Mt. San Jacinto College</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/learn/learn-chinese" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/2c/ffe2403eb411e4862c25f03480cef0/1280x720.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/2c/ffe2403eb411e4862c25f03480cef0/1280x720.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-course-photos.s3.amazonaws.com/2c/ffe2403eb411e4862c25f03480cef0/1280x720.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.1.0.0">Chinese for Beginners</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$mTJHKj0pEeSGwyIACxCdDw.0.0.1.0.1.0">Peking University</span></div>
# </div></div>
# </div></div></a><a data-click-key="catalog.click.offering_card" href="/course/humanlanguage" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-2559"><div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-2559.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-2559.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-2559.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/6f/12f8d06e7911e492e1d1bade807569/Pieter_Bruegel_the_Elder_-_The_Tower_of_Babel__Vienna__-_Google_Art_Project_-_edited.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/6f/12f8d06e7911e492e1d1bade807569/Pieter_Bruegel_the_Elder_-_The_Tower_of_Babel__Vienna__-_Google_Art_Project_-_edited.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/6f/12f8d06e7911e492e1d1bade807569/Pieter_Bruegel_the_Elder_-_The_Tower_of_Babel__Vienna__-_Google_Art_Project_-_edited.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0language-and-literature.1.0.$v1-2559.0.0.0.0"></div>
# ...
# } catch(e) {
#   var versionedPaths = {};
# }
# var baseAssetUrl = 'https://d3njjcbhbojbot.cloudfront.net/web/';
#
# for (var path in versionedPaths) {
#   require.paths[path.replace('.js', '')] = baseAssetUrl + versionedPaths[path].replace('.js', '');
# }</script><script>var loadScript = function(url, success, async) {
#   var newScript = document.createElement('script');
#   var scripts = document.getElementsByTagName('script');
#
#   newScript.type = 'text/javascript';
#   newScript.async = async || false;
#   newScript.crossorigin = 'anonymous';
#
#   if (success) {
#     if (newScript.addEventListener) {
#       newScript.addEventListener('load', function() {
#        success();
#       }, false);
#     } else if(newScript.readyState) {
#       newScript.onreadystatechange = function() {
#         if (this.readyState == 'complete') {
#           newScript.onreadystatechange = null;
#           success();
#         }
#       };
#     }
#   }
#
#   if (scripts && scripts.length) {
#     var lastScript = scripts[scripts.length - 1];
#     lastScript.parentNode.insertBefore(newScript, lastScript.nextSibling);
#   } else if (window.document && window.document.body) {
#     window.document.body.appendChild(newScript);
#   }
#
#   // IE9 will execute the proper order if src is set AFTER injection
#   newScript.src = url;
# }
#
# </script><script>var loadRequireStubs = function() {(function() {
#   var createNode = require.createNode;
#   require.createNode = function(config, moduleName, url) {
#     var scriptNode = createNode.apply(this, arguments);
#     var assetUrl = 'https://d3njjcbhbojbot.cloudfront.net/web/';
#     var forwardSlash = /^\//;
#     if ((new RegExp(assetUrl)).test(url) || forwardSlash.test(url)) {
#       scriptNode.setAttribute('crossorigin', 'anonymous');
#     }
#     return scriptNode;
#   };
# })();define('js/app/config', [], function() {
#   var config = JSON.parse('{"debug":false,"environment":"production","log":"error","out":"js/app/config.js","dir":{"home":"/"},"url":{"api":"/maestro/api/","maestro":"/maestro/api/","base":"https://www.coursera.org/","cloudfront_api":"https://d1hpa2gdx2lr6r.cloudfront.net/maestro/api/","accounts":"https://accounts.coursera.org/","assets":"https://d3njjcbhbojbot.cloudfront.net/web/","resource_assets":"https://coursera_assets.s3.amazonaws.com/","app_assets":"https://d3njjcbhbojbot.cloudfront.net/web/2640a618f0be8f7b58032f8d972ecf7662320cd8/","imageProxyRoot":"https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/"},"version":"2640a618f0be8f7b58032f8d972ecf7662320cd8","gapi_eventing_data":{"project_number":"274249572679","api_key":"","client_id":"274249572679-al8nc3ttcavj0n91due232a3h6s3r9vk.apps.googleusercontent.com"},"bigquery":{"dataset":"mydataset","table_prefix":"livedata_"}}');
#   if (config) {    config.requestCountryCode = 'ES';
#     return config;
#   } else {
#     return {};
#   }
# });window.prerenderReady = false;// Provide a string that will be replaced by edge.
# // Make sure to use double quotes because edge only escapes double quotes.
# // Then check that edge actually did the replacement.
# // Otherwise return an empty object.
# define('bundles/epic/data/overrides', [], function() {
#   var injectedString = "{\"elements\":[{\"id\":0,\"namespace\":\"payments\",\"parameterName\":\"sparkPaymentsInGringotts\",\"experimentId\":\"fudkcNgpEeSqkYGQJ8cHlw\",\"variantId\":\"ra58cefUTtaVghYFW7Fl2A\",\"value\":{\"development\":[5000006],\"testing\":[],\"staging\":[],\"production\":[974820,974608,972963,974644,973866,975068,975020,972886,972945,975350]},\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":1,\"namespace\":\"Growth\",\"parameterName\":\"searchTopicAvailable\",\"experimentId\":\"gAv0kFBJEeW5MVvg_2h26Q\",\"variantId\":\"WDpesFOrSM6K6jv_gKLq1Q\",\"value\":true,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":2,\"namespace\":\"siteCatalog\",\"parameterName\":\"numRelatedCourses\",\"experimentId\":\"yjoe0Ma-EeSuwYfluGPDdA\",\"variantId\":\"18PXoHtJTfy8PXptGOUI1w\",\"value\":9,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":3,\"namespace\":\"epicSanityTest\",\"parameterName\":\"byUrlAATest\",\"experimentId\":\"OUxDMOI5EeSBHlt3m4P7NA\",\"variantId\":\"IqRbx092QB-egQrBzyfrAw\",\"value\":\"#BABABA\",\"status\":\"RUNNING\",\"idForAllocation\":\"/browse/arts-and-humanities\",\"version\":1},{\"id\":4,\"namespace\":\"epicSanityTest\",\"parameterName\":\"bySessionAllocationTest\",\"experimentId\":\"D8MboOOTEeS9AxsvPmsp6g\",\"variantId\":\"FO_iZOCTRJyXmCBbBcB0lg\",\"value\":0.2,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":5,\"namespace\":\"siteOnDemandCompletion\",\"parameterName\":\"showSessionsCourses\",\"experimentId\":\"TsFP0Ao-EeW_uHMVHN0KpA\",\"variantId\":\"mqncHQvxSO25X08hBBF6sA\",\"value\":{\"development\":[],\"staging\":[],\"production\":[\"WChOZHTVEeSi3yIACzSGcw\",\"Auue1KA-EeS9VCIACyUcdg\",\"mG1NQnUvEeS8UyIACzYI5Q\",\"2UHGXkNtEeSfwCIACxeXRw\",\"Gtv4Xb1-EeS-ViIACwYKVQ\",\"A0IYf6jOEeSnlCIAC1EMbw\",\"GdeNrll1EeSROyIACtiVvg\",\"21IE8mqeEeSCnCIAC0ETWQ\",\"d8F1aSA5EeWXzxJxfIL00w\",\"-qKIDPnAEeS1QCIACy-KcQ\",\"SpWNUyTfEeWxbhIkPfddLQ\"]},\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":6,\"namespace\":\"siteMisc\",\"parameterName\":\"enableAutoMobileDeepLink\",\"experimentId\":\"chutEEhTEeWFyLVAkWqlXg\",\"variantId\":\"5Snx1VSLRzeTIBi5COjNSQ\",\"value\":true,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":7,\"namespace\":\"siteCatalog\",\"parameterName\":\"showPreEnrollCourses\",\"experimentId\":\"6bAesCwfEeW4xcMAp3RbZw\",\"variantId\":\"KrJyxYVOR_meSnWU41Q0Ag\",\"value\":true,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":8,\"namespace\":\"Growth\",\"parameterName\":\"useCombinedSearch\",\"experimentId\":\"mgSm4GP9EeWuPSfpEKRjjw\",\"variantId\":\"xFKbUx8hSkSiFXdXoBQwMA\",\"value\":false,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":9,\"namespace\":\"Growth\",\"parameterName\":\"showBrowseFilters\",\"experimentId\":\"J8lmkGPhEeW264lvr6wWLQ\",\"variantId\":\"GL8oSsldSVKdbjSlIJoy6Q\",\"value\":true,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":10,\"namespace\":\"Growth\",\"parameterName\":\"showSpanishLaunchPromoUnit\",\"experimentId\":\"J8lmkGPhEeW264lvr6wWLQ\",\"variantId\":\"GL8oSsldSVKdbjSlIJoy6Q\",\"value\":true,\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":11,\"namespace\":\"siteLoggedOutHomepage\",\"parameterName\":\"epicSanityCheck\",\"experimentId\":\"gMOjkK2tEeS77ZOYvk9AFA\",\"variantId\":\"a9gY3h9VRHqTaNMUy25ISQ\",\"value\":\"#ABABAB\",\"status\":\"RUNNING\",\"idForAllocation\":\"7988558576-1443307158320\",\"version\":1},{\"id\":12,\"namespace\":\"featureBlacklist\",\"parameterName\":\"privacyUsers\",\"experimentId\":\"_OvcUBwtEeWHaIGkK0VUdA\",\"variantId\":\"RwcPRcvnSBaZcRvzhma6ow\",\"value\":[\"c3505fbfa8eef219a2076583c86352c9\",\"56fa950469 ...
#
#   if (injectedString.search('EPIC_SITE_HOME_PLACEHOLDER') >= 0) {
#     return {};
#   }
#   var epicResponse = injectedString && injectedString !== undefined ? JSON.parse(injectedString) : {};
#
#   return epicResponse.elements || {};
# });
# /* eslint-disable quotes */
# // Defines a named AMD module containing the logged-in user's json
# define('pages/home/models/user.json', [], function() {
#   var userJson = "undefined";
#   if (userJson && userJson !== 'undefined') {
#     return JSON.parse(userJson);
#   } else {
#     return null;
#   }
# });
# /* eslint-disable quotes */
# // Defines a named AMD module containing the course ID
# define('bundles/phoenix/courseId', [], function() {
#   return "{{ ONDEMAND_COURSE_ID_PLACEHOLDER }}";
# });
#  window.logRequireError = function(Error) {
#    var message = Error.message || 'undefined';
#    var log = 'requirejs error (type:' + Error.requireType + ', message:' + message + ')';
#    window.onerror(
#      log,
#      window.location.href,
#      1,
#      1,
#      Error
#    );
#  }; window.require.onError = window.logRequireError;};</script><!--[if lte IE 9]><script>var queueScript = function(scripts, callback) {
#   return function() {
#     if (scripts.length > 1) {
#       loadScript(scripts.shift(), queueScript(scripts, callback));
#     } else {
#       loadScript(scripts.shift(), callback);
#     }
#   }
# };
#
# var queue = function(scripts, callback) {
#   queueScript(scripts, callback)();
# }
#
# var scripts = [
#   'https://d3njjcbhbojbot.cloudfront.net/web/bundles/vendor/Intl.js.v0-1-4/Intl.en-US.js',
#   "https://d3njjcbhbojbot.cloudfront.net/web/" + versionedPaths['js/app/preloader.js'],
#   "https://d3njjcbhbojbot.cloudfront.net/web/" + versionedPaths['js/app/loader.js'],
#   "https://d3njjcbhbojbot.cloudfront.net/web/" + versionedPaths['pages/catalog/startApp.js']
# ];
#
# queue(scripts, function() {
#   loadRequireStubs();
#   require(['js/app/preloader'], function(preloader) {
#     preloader.instrumentIfSsr();
#   });
#   require(['js/app/loader'], function(load) {
#     load('pages/catalog/startApp');
#   });
# });</script><![endif]-->
# <!--[if !IE]> --><script>if (!window.JSON) {
#   loadScript('https://d3njjcbhbojbot.cloudfront.net/web/js/vendor/json2.js');
# }
#
# if (!window.Intl) {
#   loadScript('https://d3njjcbhbojbot.cloudfront.net/web/bundles/vendor/Intl.js.v0-1-4/Intl.en-US.js');
# }
# </script><script>// the loadScript events order will be preserved by execution
# // however, the two require calls happen async, so except for loading of the static libraries
# // they should not depend on each other (execution wise)
# loadScript("https://d3njjcbhbojbot.cloudfront.net/web/" + versionedPaths['js/app/preloader.js'], function() {
#   loadRequireStubs();
#   require(['js/app/preloader'], function(preloader) {
#     preloader.instrumentIfSsr();
#     preloader.attemptDeepLinkIfMobile();
#   });
# });
# loadScript("https://d3njjcbhbojbot.cloudfront.net/web/" + versionedPaths['js/app/loader.js']);
# loadScript("https://d3njjcbhbojbot.cloudfront.net/web/" + versionedPaths['pages/catalog/startApp.js'], function() {
#   require(['js/app/loader'], function(load) {
#     load('pages/catalog/startApp');
#   });
# });</script><!-- <![endif]--><script>
#     window.App={"context":{"dispatcher":{"stores":{"ApplicationStore":{"csrfToken":"1444171158.6HYOjQbFLOlQGAp1","currentRoute":{"path":"\u002Fbrowse\u002Farts-and-humanities","action":null,"pathname":"\u002Fbrowse\u002Farts-and-humanities","routes":[{"name":"app","path":"\u002F","paramNames":[],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e},"childRoutes":[{"name":"browse","path":"\u002Fbrowse\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function RouteHandler(){i(this,RouteHandler),null!=t&&t.apply(this,arguments)},"defaultRoute":{"path":"\u002Fbrowse\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":true,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}},"childRoutes":[{"path":"\u002Fbrowse\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":true,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}},{"name":"domain","path":"\u002Fbrowse\u002F?\u002F:domainId","paramNames":["domainId"],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}},{"name":"subdomain","path":"\u002Fbrowse\u002F?\u002F:domainId\u002F:subdomainId","paramNames":["domainId","subdomainId"],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}}]},{"name":"search","path":"\u002Fcourses\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}},{"name":"spanish","path":"\u002Fnavegar\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}},{"path":"\u002F*","paramNames":["splat"],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":true,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}}],"notFoundRoute":{"path":"\u002F*","paramNames":["splat"],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":true,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this.props=n,this.context=r,this.state=null;var e=this.getInitialState?this.getInitialState():null;t("object"==typeof e&&!Array.isArray(e)),this.state=e}}},{"name":"browse","path":"\u002Fbrowse\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":false,"isNotFound":false,"handler":function RouteHandler(){i(this,RouteHandler),null!=t&&t.apply(this,arguments)},"defaultRoute":{"path":"\u002Fbrowse\u002F?","paramNames":[],"ignoreScrollBehavior":false,"isDefault":true,"isNotFound":false,"handler":function (n,r){this.__reactAutoBindMap&&c(this),this ...
#
# </script>
# </body>
# </html>

# %% [markdown]
# ### Visualizando el árbol DOM

# %% [markdown]
# ## 3. Inspeccionar la página en el navegador

# %% [markdown]
# ### XPath

# %%
courses = tree.xpath("//div[@class='rc-OfferingCard']")

# %%
print etree.tostring(courses[1], pretty_print=True,  method = 'html')
# Out:
# <div class="rc-OfferingCard" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0"><div class="bt3-row" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0">
# <div class="bt3-col-xs-3 bt3-col-sm-2" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.0"><img src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/d8/96bb86b6f727c154bb07d83cf2674c/deek_courselogo.jpg?auto=format&amp;dpr=1&amp;w=100&amp;h=100&amp;fit=crop" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/d8/96bb86b6f727c154bb07d83cf2674c/deek_courselogo.jpg?auto=format&amp;dpr=2&amp;w=100&amp;h=100&amp;fit=crop 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/d8/96bb86b6f727c154bb07d83cf2674c/deek_courselogo.jpg?auto=format&amp;dpr=3&amp;w=100&amp;h=100&amp;fit=crop 3x" class="offering-image" width="100" height="100" style="max-width:100px;max-height:100px;" alt="" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.0.0"></div>
# <div class="bt3-col-xs-8 bt3-col-xs-offset-1 bt3-col-sm-10 bt3-col-sm-offset-0" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1"><div class="offering-info" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0">
# <h2 data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0.0">Roman Architecture</h2>
# <div class="text-light" data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0.1"><span data-reactid=".27o3oqaqeww.1.0.1.0.0.3.1:$?limit=05&amp;q=0bySubdomain&amp;subdomainId=0history.1.0.$v1-678.0.0.1.0.1.0">Yale University</span></div>
# </div></div>
# </div></div>

# %%
for i in courses:
    title = i.xpath("div//h2/text()")
    url = i.xpath("div//h2/@data-reactid")
    university = i.xpath("div//*[@class='text-light']/span/text()")
    image_url = i.xpath("div//img[@class='offering-image']/@src")
    print title, url, university,image_url

# %%
links = tree.xpath("//a[@data-click-key='catalog.click.offering_card']")

for link in links:
    href = link.get('href')
    url_reactid = link.get('data-reactid')
    print href, url_reactid

# %% [markdown]
# ## Advanced scraping
#
#   * Beautiful Soup - puede leer y corregir HTML mal formado
#   * Selenium - Automatización de tareas en el browser. Páginas que usan JavaScrpit para _renderizar_
#   * Scrapy - implementa un _framework_ completo de _screen scrapping_
#      * Crawling,
#      * Planificacion y gestión de la frontera
#      * Soporte a la depuracion y desarrollo
#      * Integra Selenium

# %%
from bs4 import BeautifulSoup

r = requests.get('https://www.coursera.org/browse/arts-and-humanities')
bsObj = BeautifulSoup(r.text)

print(bsObj.findAll('h2'))
