# %% [markdown]
# # Part of Speech Tagging

# %% [markdown]
# Part of Speech = Word classes = lexical categories
#
# POS tagging: Process a sequence of words and attach the part of speech tag to each word
#
# Define what is a tagset
# What are the most common tags
# What are the most comon tagsets - difference in detail

# %%
import nltk

text = nltk.word_tokenize("And now for something completely different.")
tagged_text = nltk.pos_tag(text)
tagged_text
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ'),
#  ('.', '.')]

# %%
nltk.help.upenn_tagset('RB')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...

# %% [markdown]
# An example to show how tags help disambiguate between functions

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")
tagged_text = nltk.pos_tag(text)
tagged_text
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
woman = text.similar('woman')
# Out:
# man time day year car moment world family house country child boy
# state job way war girl place word work

# %% [markdown]
# ## Tagged corpora

# %%
tagged_words = nltk.corpus.brown.tagged_words()
tagged_words[0:20]
# Out:
# [(u'The', u'AT'),
#  (u'Fulton', u'NP-TL'),
#  (u'County', u'NN-TL'),
#  (u'Grand', u'JJ-TL'),
#  (u'Jury', u'NN-TL'),
#  (u'said', u'VBD'),
#  (u'Friday', u'NR'),
#  (u'an', u'AT'),
#  (u'investigation', u'NN'),
#  (u'of', u'IN'),
#  (u"Atlanta's", u'NP$'),
#  (u'recent', u'JJ'),
#  (u'primary', u'NN'),
#  (u'election', u'NN'),
#  (u'produced', u'VBD'),
#  (u'``', u'``'),
#  (u'no', u'AT'),
#  (u'evidence', u'NN'),
#  (u"''", u"''"),
#  (u'that', u'CS')]

# %%
tagged_sentences = nltk.corpus.brown.tagged_sents()
tagged_sentences[0:1]
# Out:
# [[(u'The', u'AT'),
#   (u'Fulton', u'NP-TL'),
#   (u'County', u'NN-TL'),
#   (u'Grand', u'JJ-TL'),
#   (u'Jury', u'NN-TL'),
#   (u'said', u'VBD'),
#   (u'Friday', u'NR'),
#   (u'an', u'AT'),
#   (u'investigation', u'NN'),
#   (u'of', u'IN'),
#   (u"Atlanta's", u'NP$'),
#   (u'recent', u'JJ'),
#   (u'primary', u'NN'),
#   (u'election', u'NN'),
#   (u'produced', u'VBD'),
#   (u'``', u'``'),
#   (u'no', u'AT'),
#   (u'evidence', u'NN'),
#   (u"''", u"''"),
#   (u'that', u'CS'),
#   (u'any', u'DTI'),
#   (u'irregularities', u'NNS'),
#   (u'took', u'VBD'),
#   (u'place', u'NN'),
#   (u'.', u'.')]]

# %% [markdown]
# Each corpus uses their own categories, universal tagset is a simplified tagset

# %%
tagged_words = nltk.corpus.brown.tagged_words(tagset='universal')
tagged_words[0:20]
# Out:
# [(u'The', u'DET'),
#  (u'Fulton', u'NOUN'),
#  (u'County', u'NOUN'),
#  (u'Grand', u'ADJ'),
#  (u'Jury', u'NOUN'),
#  (u'said', u'VERB'),
#  (u'Friday', u'NOUN'),
#  (u'an', u'DET'),
#  (u'investigation', u'NOUN'),
#  (u'of', u'ADP'),
#  (u"Atlanta's", u'NOUN'),
#  (u'recent', u'ADJ'),
#  (u'primary', u'NOUN'),
#  (u'election', u'NOUN'),
#  (u'produced', u'VERB'),
#  (u'``', u'.'),
#  (u'no', u'DET'),
#  (u'evidence', u'NOUN'),
#  (u"''", u'.'),
#  (u'that', u'ADP')]

# %%
from nltk.corpus import brown 

brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word,tag) in brown_news_tagged)
tag_fd.most_common() # most common POs tags in the news part of the brown corpus
# Out:
# [(u'NOUN', 30640),
#  (u'VERB', 14399),
#  (u'ADP', 12355),
#  (u'.', 11928),
#  (u'DET', 11389),
#  (u'ADJ', 6706),
#  (u'ADV', 3349),
#  (u'CONJ', 2717),
#  (u'PRON', 2535),
#  (u'PRT', 2264),
#  (u'NUM', 2166),
#  (u'X', 106)]

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)
noun_preceders = [a[1] for (a,b) in word_tag_pairs if b[1]  == 'NOUN'] # etiquetas que preceden más comunmente a un nombre 
fdist = nltk.FreqDist(noun_preceders)
fdist.most_common()
# Out:
# [(u'NOUN', 7959),
#  (u'DET', 7363),
#  (u'ADJ', 4758),
#  (u'ADP', 3781),
#  (u'.', 2795),
#  (u'VERB', 1842),
#  (u'CONJ', 938),
#  (u'NUM', 894),
#  (u'ADV', 186),
#  (u'PRT', 94),
#  (u'PRON', 19),
#  (u'X', 11)]

# %%
word_tag_fd = nltk.FreqDist(brown_news_tagged)
[wt[0] for (wt,_) in word_tag_fd.most_common() if wt[1] == 'VERB'][0:20] # Verbos mas comunes
# Out:
# [u'is',
#  u'was',
#  u'be',
#  u'said',
#  u'will',
#  u'are',
#  u'has',
#  u'had',
#  u'have',
#  u'were',
#  u'would',
#  u'been',
#  u'made',
#  u'can',
#  u'could',
#  u'get',
#  u'may',
#  u'did',
#  u'do',
#  u'should']

# %%
tagCfd = nltk.ConditionalFreqDist(brown_news_tagged)
tagCfd['play'].most_common()
# Out:
# [(u'VERB', 30), (u'NOUN', 11)]

# %%
wordCfd = nltk.ConditionalFreqDist((tag,word) for (word,tag) in brown_news_tagged)
wordCfd['VERB']
# Out:
# FreqDist({u'is': 732, u'was': 717, u'be': 526, u'said': 402, u'will': 388, u'are': 328, u'has': 300, u'had': 279, u'have': 265, u'were': 252, ...})

# %%
wsj = nltk.corpus.treebank.tagged_words()
cfd = nltk.ConditionalFreqDist(wsj)
cfd['play'].most_common()
# Out:
# [(u'VB', 3), (u'VBP', 1), (u'NN', 1)]

# %%
sorted([w for w in cfd.conditions() if 'VBD' in cfd[w] and 'VBN' in cfd[w]])
# Out:
# [u'Asked',
#  u'accelerated',
#  u'accepted',
#  u'accused',
#  u'acquired',
#  u'added',
#  u'adopted',
#  u'advanced',
#  u'advised',
#  u'agreed',
#  u'aimed',
#  u'alleged',
#  u'allowed',
#  u'announced',
#  u'anticipated',
#  u'applied',
#  u'approved',
#  u'argued',
#  u'asked',
#  u'assumed',
#  u'assured',
#  u'attached',
#  u'attempted',
#  u'attributed',
#  u'awarded',
#  u'backed',
#  u'banned',
#  u'barred',
#  u'believed',
#  u'blamed',
#  u'boosted',
#  u'bought',
#  u'bribed',
#  u'brought',
#  u'built',
#  u'called',
#  u'carried',
#  u'caused',
#  u'changed',
#  u'chastised',
#  u'cited',
#  u'climbed',
#  u'closed',
#  u'collapsed',
#  u'committed',
#  u'compared',
#  u'complained',
#  u'completed',
#  u'concluded',
#  u'condemned',
#  u'confirmed',
#  u'consented',
#  u'contained',
#  u'continued',
#  u'contributed',
#  u'controlled',
#  u'covered',
#  u'created',
#  u'cut',
#  u'damaged',
#  u'decided',
#  u'declared',
#  u'deemed',
#  u'denied',
#  u'described',
#  u'determined',
#  u'developed',
#  u'died',
#  u'disclosed',
#  u'discovered',
#  u'discussed',
#  u'dismissed',
#  u'dominated',
#  u'dropped',
#  u'dumped',
#  u'earned',
#  u'edged',
#  u'eliminated',
#  u'ended',
#  u'endorsed',
#  u'entered',
#  u'estimated',
#  u'examined',
#  u'expanded',
#  u'expelled',
#  u'expressed',
#  u'extended',
#  u'failed',
#  u'favored',
#  u'feared',
#  u'fed',
#  u'felt',
#  u'filed',
#  u'finished',
#  u'fired',
#  u'followed',
#  u'forced',
#  u'forecast',
#  u'formed',
#  u'found',
#  u'fueled',
#  u'gained',
#  u'got',
#  u'had',
#  u'halted',
#  u'hampered',
#  u'heard',
#  u'held',
#  u'helped',
#  u'hired',
#  u'hit',
#  u'identified',
#  u'imported',
#  u'imposed',
#  u'included',
#  u'increased',
#  u'indicated',
#  u'intended',
#  u'introduced',
#  u'invented',
#  u'invested',
#  u'involved',
#  u'issued',
#  u'jumped',
#  u'kept',
#  u'kicked',
#  u'killed',
#  u'launched',
#  u'learned',
#  u'led',
#  u'left',
#  u'lent',
#  u'licensed',
#  u'lifted',
#  u'limited',
#  u'lost',
#  u'lowered',
#  u'made',
#  u'maintained',
#  u'managed',
#  u'marketed',
#  u'matched',
#  u'meant',
#  u'merged',
#  u'met',
#  u'mixed',
#  u'mounted',
#  u'moved',
#  u'named',
#  u'needed',
#  u'negotiated',
#  u'nominated',
#  u'noted',
#  u'obligated',
#  u'observed',
#  u'obtained',
#  u'offered',
#  u'omitted',
#  u'opened',
#  u'opposed',
#  u'ordered',
#  u'owed',
#  u'paid',
#  u'passed',
#  u'placed',
#  u'planned',
#  u'plunged',
#  u'pointed',
#  u'polled',
#  u'posted',
#  u'preferred',
#  u'presented',
#  u'printed',
#  u'produced',
#  u'prompted',
#  u'proposed',
#  u'proved',
#  u'provided',
#  u'purchased',
#  u'pushed',
#  u'put',
#  u'quoted',
#  u'raised',
#  u'ranged',
#  u'rated',
#  u'reached',
#  u'read',
#  u'received',
#  u'recorded',
#  u'reduced',
#  u'referred',
#  u'reflected',
#  u'refused',
#  u'registered',
#  u'rejected',
#  u'released',
#  u'remarked',
#  u'removed',
#  u'renewed',
#  u'replaced',
#  u'reported',
#  u'represented',
#  u'required',
#  u'responded',
#  u'restructured',
#  u'resulted',
#  u'retired',
#  u'returned',
#  u'rolled',
#  u'said',
#  u'scheduled',
#  u'scrambled',
#  u'secured',
#  u'sent',
#  u'served',
#  u'set',
#  u'settled',
#  u'signed',
#  u'snapped',
#  u'soared',
#  u'sold',
#  u'solved',
#  u'sought',
#  u'sparked',
#  u'speculated',
#  u'spent',
#  u'squeezed',
#  u'started',
#  u'stated',
#  u'stepped',
#  u'stopped',
#  u'stressed',
#  u'studied',
#  u'supported',
#  u'surfaced',
#  u'surged',
#  u'suspended',
#  u'sweetened',
#  u'switched',
#  u'terminated',
#  u'thought',
#  u'threatened',
#  u'tied',
#  u'told',
#  u'transformed',
#  u'treated',
#  u'tried',
#  u'triggered',
#  u'tripled',
#  u'turned',
#  u'understood',
#  u'upheld',
#  u'used',
#  u'viewed',
#  u'voted',
#  u'vowed',
#  u'wanted',
#  u'warned',
#  u'welcomed',
#  u'won',
#  u'worked']

# %%
idx1 = wsj.index(('kicked','VBD'))
wsj[idx1-4:idx1+4]
# Out:
# [(u'While', u'IN'),
#  (u'program', u'NN'),
#  (u'trades', u'NNS'),
#  (u'swiftly', u'RB'),
#  (u'kicked', u'VBD'),
#  (u'in', u'IN'),
#  (u',', u','),
#  (u'a', u'DT')]

# %%
idx2 = wsj.index(('kicked','VBN'))
wsj[idx2-4:idx2+4]
# Out:
# [(u'head', u'NN'),
#  (u'of', u'IN'),
#  (u'state', u'NN'),
#  (u'has', u'VBZ'),
#  (u'kicked', u'VBN'),
#  (u'off', u'RP'),
#  (u'an', u'DT'),
#  (u'issue', u'NN')]

# %%
def process(sentence):
    for (w1,t1), (w2,t2), (w3,t3) in nltk.trigrams(sentence):
        if (t1.startswith('V') and t2 == 'TO' and t3.startswith('V')):
            return w1 + " " + w2 + " " + w3


phrases = [process(tagged_sent) for tagged_sent in brown.tagged_sents()]
phraseFd = nltk.FreqDist(phrases)
phraseFd.most_common()
# Out:
# [(None, 53489),
#  (u'trying to get', 13),
#  (u'want to see', 10),
#  (u'going to get', 10),
#  (u'trying to make', 10),
#  (u'want to go', 9),
#  (u'wanted to know', 7),
#  (u'going to take', 7),
#  (u'wanted to go', 6),
#  (u'trying to find', 6),
#  (u'want to make', 6),
#  (u'want to know', 6),
#  (u'tried to make', 6),
#  (u'got to get', 6),
#  (u'got to know', 5),
#  (u'used to say', 5),
#  (u'expect to find', 5),
#  (u'going to tell', 5),
#  (u'want to leave', 5),
#  (u'like to see', 5),
#  (u'like to think', 5),
#  (u'permitted to operate', 5),
#  (u'want to talk', 5),
#  (u'surprised to find', 4),
#  (u'wanted to get', 4),
#  (u'try to keep', 4),
#  (u'failed to show', 4),
#  (u'began to talk', 4),
#  (u'going to kill', 4),
#  (u'allowed to stand', 4),
#  (u'began to feel', 4),
#  (u'entitled to sue', 4),
#  (u'designed to provide', 4),
#  (u'used to measure', 4),
#  (u'wanted to take', 4),
#  (u'like to make', 4),
#  (u'come to see', 4),
#  (u'trying to keep', 4),
#  (u'used to describe', 4),
#  (u'want to buy', 4),
#  (u'like to know', 4),
#  (u'refused to let', 4),
#  (u'began to move', 4),
#  (u'seems to refer', 3),
#  (u'tried to keep', 3),
#  (u'failed to reach', 3),
#  (u'wait to get', 3),
#  (u'designed to reflect', 3),
#  (u'wished to make', 3),
#  (u'tried to see', 3),
#  (u'used to keep', 3),
#  (u'need to know', 3),
#  (u'trying to say', 3),
#  (u'decided to leave', 3),
#  (u'decided to stay', 3),
#  (u'expected to report', 3),
#  (u'began to crawl', 3),
#  (u'going to make', 3),
#  (u'meant to say', 3),
#  (u'required to file', 3),
#  (u'afford to lose', 3),
#  (u'tend to become', 3),
#  (u'seemed to know', 3),
#  (u'refused to permit', 3),
#  (u'going to let', 3),
#  (u'expect to get', 3),
#  (u'extended to include', 3),
#  (u'equipped to handle', 3),
#  (u'wanted to make', 3),
#  (u'designed to prevent', 3),
#  (u'beginning to get', 3),
#  (u'used to play', 3),
#  (u'required to make', 3),
#  (u'trying to prove', 3),
#  (u'used to provide', 3),
#  (u'started to say', 3),
#  (u'try to get', 3),
#  (u'refused to give', 3),
#  (u'needed to make', 3),
#  (u'going to work', 3),
#  (u'prepared to accept', 3),
#  (u'required to pass', 3),
#  (u'asked to see', 3),
#  (u'tried to explain', 3),
#  (u'came to know', 3),
#  (u'began to weep', 3),
#  (u'made to look', 3),
#  (u'like to talk', 3),
#  (u'decided to go', 3),
#  (u'want to hear', 3),
#  (u'want to get', 3),
#  (u'used to make', 3),
#  (u'trying to talk', 3),
#  (u'seem to indicate', 3),
#  (u'mean to say', 3),
#  (u'want to ask', 3),
#  (u'mean to imply', 3),
#  (u'seemed to think', 3),
#  (u'pleased to note', 3),
#  (u'try to stop', 3),
#  (u'tried to push', 2),
#  (u'come to pass', 2),
#  (u'got to take', 2),
#  (u'seem to believe', 2),
#  (u'expected to supply', 2),
#  (u'intended to provide', 2),
#  (u'trying to put', 2),
#  (u'meant to help', 2),
#  (u'wanted to keep', 2),
#  (u'impelled to make', 2),
#  (u'learn to portray', 2),
#  (u'used to look', 2),
#  (u'prepared to demonstrate', 2),
#  (u'seem to think', 2),
#  (u'decided to seek', 2),
#  (u'began to show', 2),
#  (u'sought to bring', 2),
#  (u'want to give', 2),
#  (u'refuse to acknowledge', 2),
#  (u'allowed to see', 2),
#  (u'threatened to ignite', 2),
#  (u'decided to see', 2),
#  (u'going to give', 2),
#  (u'want to use', 2),
#  (u'meant to convey', 2),
#  (u'tried to describe', 2),
#  (u'began to write', 2),
#  (u'wanted to buy', 2),
#  (u'began to develop', 2),
#  (u'altered to show', 2),
#  (u'wish to preserve', 2),
#  (u'compelled to spend', 2),
#  (u'live to see', 2),
#  (u'turned to look', 2),
#  (u'wanted to run', 2),
#  (u'made to replace', 2),
#  (u'going to become', 2),
#  (u'helping to strengthen', 2),
#  (u'began to think', 2),
#  (u'required to furnish', 2),
#  (u'designed to give', 2),
#  (u'going to see', 2),
#  (u'began to nod', 2),
#  (u'paused to look', 2),
#  (u'began to speak', 2),
#  (u'wants to study', 2),
#  (u'want to take', 2),
#  (u'lived to see', 2),
#  (u'wanted to show', 2),
#  (u'tried to bring', 2),
#  (u'continue to live', 2),
#  (u'agreed to take', 2),
#  (u'tried to stop', 2),
#  (u'used to name', 2),
#  (u'elect to use', 2),
#  (u'wanted to write', 2),
#  (u'going to need', 2),
#  (u'got to run', 2),
#  (u'begin to play', 2),
#  (u'used to tell', 2),
#  (u'appears to lie', 2),
#  (u'turned to face', 2),
#  (u'tried to persuade', 2),
#  (u'compelled to make', 2),
#  (u'used to separate', 2),
#  (u'determined to avoid', 2),
#  (u'try to make', 2),
#  (u'seemed to indicate', 2),
#  (u'shuddered to think', 2),
#  (u'wanted to see', 2),
#  (u'come to say', 2),
#  (u'hastened to add', 2),
#  (u'seemed to understand', 2),
#  (u'got to go', 2),
#  (u'sought to make', 2),
#  (u'seemed to promise', 2),
#  (u'learning to read', 2),
#  (u'permitted to see', 2),
#  (u'permitted to rebut', 2),
#  (u'supposed to make', 2),
#  (u'learn to like', 2),
#  (u'continued to come', 2),
#  (u'began to whip', 2),
#  (u'required to reach', 2),
#  (u'amended to read', 2),
#  (u'want to miss', 2),
#  (u'surprised to see', 2),
#  (u'invited to participate', 2),
#  (u'come to recognize', 2),
#  (u'going to happen', 2),
#  (u'want to say', 2),
#  (u'determined to get', 2),
#  (u'began to walk', 2),
#  (u'continue to make', 2),
#  (u'gone to live', 2),
#  (u'got to put', 2),
#  (u'scheduled to go', 2),
#  (u'began to creep', 2),
#  (u'continues to add', 2),
#  (u'refused to attend', 2),
#  (u'designed to handle', 2),
#  (u'demanding to know', 2),
#  (u'begin to look', 2),
#  (u'wish to deny', 2),
#  (u'made to appear', 2),
#  (u'used to specify', 2),
#  (u'managed to get', 2),
#  (u'proceeded to give', 2),
#  (u'decided to try', 2),
#  (u'beginning to feel', 2),
#  (u'hopes to find', 2),
#  (u'like to hear', 2),
#  (u'try to solve', 2),
#  (u'want to find', 2),
#  (u'prepared to act', 2),
#  (u'going to allow', 2),
#  (u'expected to earn', 2),
#  (u'served to increase', 2),
#  (u'waiting to see', 2),
#  (u'like to go', 2),
#  (u'started to cross', 2),
#  (u'begin to see', 2),
#  (u'expected to give', 2),
#  (u'wanted to kill', 2),
#  (u'trying to pull', 2),
#  (u'designed to reduce', 2),
#  (u'learned to write', 2),
#  (u'fear to negotiate', 2),
#  (u'began to build', 2),
#  (u'expected to increase', 2),
#  (u'like to suggest', 2),
#  (u'combine to provide', 2),
#  (u'like to bring', 2),
#  (u'inclined to think', 2),
#  (u'refusing to think', 2),
#  (u'try to cut', 2),
#  (u'going to put', 2),
#  (u'made to take', 2),
#  (u'going to die', 2),
#  (u'started to slump', 2),
#  (u'used to take', 2),
#  (u'attempt to act', 2),
#  (u'want to risk', 2),
#  (u'fail to convey', 2),
#  (u'expect to see', 2),
#  (u'want to study', 2),
#  (u'tried to think', 2),
#  (u'relieved to see', 2),
#  (u'wanted to turn', 2),
#  (u'bother to look', 2),
#  (u'trying to worry', 2),
#  (u'supposed to put', 2),
#  (u'seeks to make', 2),
#  (u'forced to admit', 2),
#  (u'seem to feel', 2),
#  (u'going to call', 2),
#  (u'like to dance', 2),
#  (u'ordered to report', 2),
#  (u'Try to find', 2),
#  (u'seeking to become', 2),
#  (u'saved to represent', 2),
#  (u'said to give', 2),
#  (u'going to prove', 2),
#  (u'began to play', 2),
#  (u'hoping to see', 2),
#  (u'continue to show', 2),
#  (u'hope to win', 2),
#  (u'seem to make', 2),
#  (u'went to see', 2),
#  (u'prepared to teach', 2),
#  (u'Try to imagine', 2),
#  (u'refused to accept', 2),
#  (u'expected to make', 2),
#  (u'expected to put', 2),
#  (u'expected to know', 2),
#  (u'tend to create', 2),
#  (u'tried to arbitrate', 2),
#  (u'decided to keep', 2),
#  (u'like to keep', 2),
#  (u'seem to know', 2),
#  (u'began to suspect', 2),
#  (u'going to listen', 2),
#  (u'tried to find', 2),
#  (u'shown to undergo', 2),
#  (u'started to run', 2),
#  (u'seem to fall', 2),
#  (u'try to run', 2),
#  (u'led to believe', 2),
#  (u'required to cut', 2),
#  (u'want to encourage', 2),
#  (u'wait to see', 2),
#  (u'wants to see', 2),
#  (u'began to fall', 2),
#  (u'started to move', 2),
#  (u'tends to express', 2),
#  (u'tends to lose', 2),
#  (u'needs to know', 2),
#  (u'going to join', 2),
#  (u'made to flow', 2),
#  (u'seems to improve', 2),
#  (u'came to see', 2),
#  (u'needed to meet', 2),
#  (u'used to select', 2),
#  (u'began to make', 2),
#  (u'want to hire', 2),
#  (u'went to visit', 2),
#  (u'seems to think', 2),
#  (u'continued to run', 2),
#  (u'going to live', 2),
#  (u'refused to believe', 2),
#  (u'liked to think', 2),
#  (u'managing to get', 2),
#  (u'wants to get', 2),
#  (u'waiting to report', 2),
#  (u'refused to change', 2),
#  (u'seemed to remember', 2),
#  (u'attempting to make', 2),
#  (u'learned to dispute', 2),
#  (u'persuaded to adopt', 2),
#  (u'thought to represent', 2),
#  (u'tried to ignore', 2),
#  (u'tried to tell', 2),
#  (u'designed to help', 2),
#  (u'tried to get', 2),
#  (u'seems to make', 2),
#  (u'get to know', 2),
#  (u'doomed to become', 2),
#  (u'fail to see', 2),
#  (u'begins to go', 1),
#  (u'decided to tackle', 1),
#  (u'Failing to heed', 1),
#  (u'ready to tick', 1),
#  (u'used to adjust', 1),
#  (u'attempts to face', 1),
#  (u'began to abuse', 1),
#  (u'allowed to reach', 1),
#  (u'came to rescue', 1),
#  (u'used to indicate', 1),
#  (u'appear to affect', 1),
#  (u'compelled to kill', 1),
#  (u'left to distract', 1),
#  (u'fit to put', 1),
#  (u'trying to hit', 1),
#  (u'tend to consider', 1),
#  (u'going to like', 1),
#  (u'need to look', 1),
#  (u'persuaded to restock', 1),
#  (u'failed to lead', 1),
#  (u'shocked to find', 1),
#  (u'trying to track', 1),
#  (u'threatening to swallow', 1),
#  (u'adjusted to supply', 1),
#  (u'seemed to disintegrate', 1),
#  (u'going to keel', 1),
#  (u'used to express', 1),
#  (u'like to question', 1),
#  (u'given to go', 1),
#  (u'attempts to trace', 1),
#  (u'attempts to weigh', 1),
#  (u'take to show', 1),
#  (u'think to look', 1),
#  (u'begun to parallel', 1),
#  (u'tried to farm', 1),
#  (u'eliminated to obtain', 1),
#  (u'wanted to invest', 1),
#  (u'start to think', 1),
#  (u'got to remember', 1),
#  (u'trying to create', 1),
#  (u'moving to take', 1),
#  (u'allowed to react', 1),
#  (u'expect to stop', 1),
#  (u'required to certify', 1),
#  (u'decide to encourage', 1),
#  (u'hastened to put', 1),
#  (u'advised to flee', 1),
#  (u'expects to extend', 1),
#  (u'determined to spend', 1),
#  (u'learned to meet', 1),
#  (u'afford to take', 1),
#  (u'appointed to study', 1),
#  (u'strive to put', 1),
#  (u'designed to become', 1),
#  (u'straining to stay', 1),
#  (u'observed to characterize', 1),
#  (u'Deciding to become', 1),
#  (u'seeking to continue', 1),
#  (u'taken to effect', 1),
#  (u'forbore to mention', 1),
#  (u'tried to economize', 1),
#  (u'made to impose', 1),
#  (u'want to thin', 1),
#  (u'ordered to attack', 1),
#  (u'wish to leave', 1),
#  (u'motivated to seek', 1),
#  (u'stopped to receive', 1),
#  (u'decides to drop', 1),
#  (u'managed to automate', 1),
#  (u'comes to represent', 1),
#  (u'ceased to grumble', 1),
#  (u'plan to add', 1),
#  (u'started to sweep', 1),
#  (u'try to study', 1),
#  (u'attempted to end', 1),
#  (u'hoped to persuade', 1),
#  (u'refusing to show', 1),
#  (u'hope to make', 1),
#  (u'beginning to collect', 1),
#  (u'learn to wear', 1),
#  (u'served to overheat', 1),
#  (u'supposed to keep', 1),
#  (u'added to reinforce', 1),
#  (u'tries to preserve', 1),
#  (u'like to offer', 1),
#  (u'allowed to claim', 1),
#  (u'planned to double', 1),
#  (u'forced to demonstrate', 1),
#  (u'amazed to find', 1),
#  (u'continued to camouflage', 1),
#  (u'plan to increase', 1),
#  (u'supposed to result', 1),
#  (u'created to accommodate', 1),
#  (u'continue to release', 1),
#  (u'known to rely', 1),
#  (u'preparing to deport', 1),
#  (u'trying to maneuver', 1),
#  (u'grew to depend', 1),
#  (u'care to get', 1),
#  (u'sought to win', 1),
#  (u'wanted to purchase', 1),
#  (u'fumbling to untie', 1),
#  (u'asked to give', 1),
#  (u'fit to kill', 1),
#  (u'trying to marry', 1),
#  (u'intend to go', 1),
#  (u'began to wish', 1),
#  (u'conpired to use', 1),
#  (u'came to meet', 1),
#  (u'hope to compete', 1),
#  (u'supposed to buy', 1),
#  (u'appear to spark', 1),
#  (u'found to protect', 1),
#  (u'used to fill', 1),
#  (u'adjusted to operate', 1),
#  (u'likes to trot', 1),
#  (u'prepared to run', 1),
#  (u'seem to recognize', 1),
#  (u'taken to minimize', 1),
#  (u'pulled to clear', 1),
#  (u'seeming to invalidate', 1),
#  (u'coded to permit', 1),
#  (u'chosen to sing', 1),
#  (u'learn to control', 1),
#  (u'inspected to determine', 1),
#  (u'determined to marry', 1),
#  (u'taken to study', 1),
#  (u'decided to spend', 1),
#  (u'prefer to see', 1),
#  (u'seen to begin', 1),
#  (u'prepared to worship', 1),
#  (u'began to change', 1),
#  (u'continuing to capture', 1),
#  (u'combined to achieve', 1),
#  (u'came to live', 1),
#  (u'begun to disturb', 1),
#  (u'compelled to find', 1),
#  (u'tried to shadow', 1),
#  (u'began to trail', 1),
#  (u'tried to flatten', 1),
#  (u'channeled to produce', 1),
#  (u'expected to entertain', 1),
#  (u'trying to tell', 1),
#  (u'seemed to antagonize', 1),
#  (u'united to push', 1),
#  (u'want to appear', 1),
#  (u'Ask to see', 1),
#  (u'pleased to see', 1),
#  (u'permitted to speculate', 1),
#  (u'used to kid', 1),
#  (u'seems to follow', 1),
#  (u'made to assure', 1),
#  (u'threatened to burst', 1),
#  (u'seeks to recapture', 1),
#  (u'wish to budget', 1),
#  (u'determined to go', 1),
#  (u'attempting to falsify', 1),
#  (u'managed to look', 1),
#  (u'want to point', 1),
#  (u'chose to read', 1),
#  (u'like to hurt', 1),
#  (u'required to localize', 1),
#  (u'inclined to extenuate', 1),
#  (u'expected to administer', 1),
#  (u'allowed to issue', 1),
#  (u'tried to discover', 1),
#  (u'want to kill', 1),
#  (u'plans to go', 1),
#  (u'used to refer', 1),
#  (u'directed to investigate', 1),
#  (u'decided to cast', 1),
#  (u'seem to concentrate', 1),
#  (u'trying to read', 1),
#  (u'kneels to kiss', 1),
#  (u'hesitate to sacrifice', 1),
#  (u'brought to bear', 1),
#  (u'wanted to play', 1),
#  (u'tried to start', 1),
#  (u'learn to identify', 1),
#  (u'try to play', 1),
#  (u'used to approach', 1),
#  (u'decided to take', 1),
#  (u'hoping to frighten', 1),
#  (u'begin to feel', 1),
#  (u'continued to arrive', 1),
#  (u'hate to run', 1),
#  (u'left to say', 1),
#  (u'chiseled to match', 1),
#  (u'aims to give', 1),
#  (u'appears to endorse', 1),
#  (u'trained to fulfill', 1),
#  (u'decided to dance', 1),
#  (u'seemed to stride', 1),
#  (u'combined to prevent', 1),
#  (u'like to hunt', 1),
#  (u'plan to discuss', 1),
#  (u'wished to wait', 1),
#  (u'left to rest', 1),
#  (u'began to review', 1),
#  (u'gone to purify', 1),
#  (u'taken to indicate', 1),
#  (u'bought to provide', 1),
#  (u'manages to acquire', 1),
#  (u'designed to avoid', 1),
#  (u'attempted to analyze', 1),
#  (u'continues to feed', 1),
#  (u'begun to spit', 1),
#  (u'promises to follow', 1),
#  (u'continues to feel', 1),
#  (u'going to eat', 1),
#  (u'sought to meet', 1),
#  (u'want to begin', 1),
#  (u'seemed to deserve', 1),
#  (u'wanted to wring', 1),
#  (u'want to let', 1),
#  (u'bent to pick', 1),
#  (u'scheduled to share', 1),
#  (u'continue to plague', 1),
#  (u'seem to snap', 1),
#  (u'managed to grow', 1),
#  (u'need to communicate', 1),
#  (u'failed to materialize', 1),
#  (u'continue to inquire', 1),
#  (u'beginning to make', 1),
#  (u'trying to catch', 1),
#  (u'cause to exist', 1),
#  (u'allowed to rust', 1),
#  (u'proceeded to search', 1),
#  (u'duplicated to form', 1),
#  (u'beginning to devise', 1),
#  (u'sent to clean', 1),
#  (u'agreed to correspond', 1),
#  (u'fails to gain', 1),
#  (u'seemed to spend', 1),
#  (u'dared to enter', 1),
#  (u'called to say', 1),
#  (u'mentioned to make', 1),
#  (u'tried to brush', 1),
#  (u'informed to report', 1),
#  (u'expected to race', 1),
#  (u'tended to float', 1),
#  (u'decided to return', 1),
#  (u'forbidden to sit', 1),
#  (u'employed to live', 1),
#  (u'come to clean', 1),
#  (u'Want to try', 1),
#  (u'forced to make', 1),
#  (u'care to count', 1),
#  (u'begun to ebb', 1),
#  (u'trying to avoid', 1),
#  (u'wanting to rent', 1),
#  (u'concerned to leave', 1),
#  (u'returned to live', 1),
#  (u'takes to drink', 1),
#  (u'seems to speak', 1),
#  (u'designed to belong', 1),
#  (u'appear to push', 1),
#  (u'assembled to bear', 1),
#  (u'hesitates to suggest', 1),
#  (u'deserve to lie', 1),
#  (u'intend to make', 1),
#  (u'want to raise', 1),
#  (u'join to defeat', 1),
#  (u'set to play', 1),
#  (u'fly to collect', 1),
#  (u'decided to remove', 1),
#  (u'decided to stop', 1),
#  (u'wished to continue', 1),
#  (u'combining to raise', 1),
#  (u'decide to clobber', 1),
#  (u'amazed to realize', 1),
#  (u'wished to see', 1),
#  (u'serve to lead', 1),
#  (u'urged to keep', 1),
#  (u'proceeded to neglect', 1),
#  (u'intends to economize', 1),
#  (u'started to pace', 1),
#  (u'chosen to serve', 1),
#  (u'wanting to unlock', 1),
#  (u'began to swing', 1),
#  (u'tending to separate', 1),
#  (u'like to re-emphasise', 1),
#  (u'expected to stay', 1),
#  (u'used to destroy', 1),
#  (u'ceased to need', 1),
#  (u'required to afford', 1),
#  (u'began to specify', 1),
#  (u'seem to reduce', 1),
#  (u'starts to ride', 1),
#  (u'arranged to fit', 1),
#  (u'seem to prefer', 1),
#  (u'tends to depict', 1),
#  (u'began to cry', 1),
#  (u'dying to defend', 1),
#  (u'expected to receive', 1),
#  (u'used to carry', 1),
#  (u'came to teach', 1),
#  (u'made to group', 1),
#  (u'forced to buy', 1),
#  (u'wanting to cut', 1),
#  (u'presumed to address', 1),
#  (u'beginning to find', 1),
#  (u'help to keep', 1),
#  (u'attempting to improve', 1),
#  (u'equipped to tell', 1),
#  (u'expected to risk', 1),
#  (u'doing to help', 1),
#  (u'began to explode', 1),
#  (u'wish to deceive', 1),
#  (u'failing to achieve', 1),
#  (u'stops to ask', 1),
#  (u'heard to say', 1),
#  (u'advanced to argue', 1),
#  (u'expect to face', 1),
#  (u'intended to obstruct', 1),
#  (u'like to rise', 1),
#  (u'sought to run', 1),
#  (u'decided to set', 1),
#  (u'tends to become', 1),
#  (u'likes to measure', 1),
#  (u'help to turn', 1),
#  (u'seem to represent', 1),
#  (u'seek to capture', 1),
#  (u'going to keep', 1),
#  (u'continued to wage', 1),
#  (u'writing to devote', 1),
#  (u'chooses to lead', 1),
#  (u'needed to bolster', 1),
#  (u'came to ask', 1),
#  (u'beginning to turn', 1),
#  (u'cease to marvel', 1),
#  (u'arrange to rent', 1),
#  (u'sought to express', 1),
#  (u'turning to cup', 1),
#  (u'determined to resist', 1),
#  (u'failed to furnish', 1),
#  (u'designed to deal', 1),
#  (u'forced to hypothesize', 1),
#  (u'allowed to spend', 1),
#  (u'told to leave', 1),
#  (u'phoned to say', 1),
#  (u'began to riffle', 1),
#  (u'want to amend', 1),
#  (u'help to reveal', 1),
#  (u'failed to make', 1),
#  (u'care to acknowledge', 1),
#  (u'began to pace', 1),
#  (u'began to pack', 1),
#  (u'liked to wring', 1),
#  (u'combined to make', 1),
#  (u'resolved to make', 1),
#  (u'started to strike', 1),
#  (u'attempting to speak', 1),
#  (u'mean to reconsider', 1),
#  (u'decided to make', 1),
#  (u'attempted to act', 1),
#  (u'stooping to dispense', 1),
#  (u'seem to dwell', 1),
#  (u'decided to break', 1),
#  (u'allowed to rest', 1),
#  (u'bent to observe', 1),
#  (u'happened to think', 1),
#  (u'committed to move', 1),
#  (u'used to think', 1),
#  (u'going to murder', 1),
#  (u'trying to develop', 1),
#  (u'seem to preserve', 1),
#  (u'come to skirt', 1),
#  (u'expect to escape', 1),
#  (u'bothering to look', 1),
#  (u'claims to show', 1),
#  (u'known to run', 1),
#  (u'born to command', 1),
#  (u'taken to rest', 1),
#  (u'trying to drag', 1),
#  (u'stayed to visit', 1),
#  (u'wished to show', 1),
#  (u'began to wonder', 1),
#  (u'come to call', 1),
#  (u'trying to sound', 1),
#  (u'like to underline', 1),
#  (u'trying to draw', 1),
#  (u'try to avoid', 1),
#  (u'hoping to escape', 1),
#  (u'want to roast', 1),
#  (u'starts to swing', 1),
#  (u'served to overcome', 1),
#  (u'failed to anticipate', 1),
#  (u'began to whirl', 1),
#  (u'want to play', 1),
#  (u'attempt to settle', 1),
#  (u'dash to get', 1),
#  (u'expect to reduce', 1),
#  (u'continue to lack', 1),
#  (u'decided to ride', 1),
#  (u'allowed to move', 1),
#  (u'used to minimize', 1),
#  (u'began to realize', 1),
#  (u'seemed to make', 1),
#  (u'seeking to increase', 1),
#  (u'wish to create', 1),
#  (u'continue to expand', 1),
#  (u'trying to emulate', 1),
#  (u'called to work', 1),
#  (u'seem to act', 1),
#  (u'concerned to stand', 1),
#  (u'seem to wink', 1),
#  (u'required to move', 1),
#  (u'like to follow', 1),
#  (u'seemed to rain', 1),
#  (u'prepared to undertake', 1),
#  (u'expected to consist', 1),
#  (u'love to run', 1),
#  (u'meant to pay', 1),
#  (u'used to fasten', 1),
#  (u'allowed to pass', 1),
#  (u'began to appear', 1),
#  (u'began to rock', 1),
#  (u'like to get', 1),
#  (u'essayed to down', 1),
#  (u'began to experience', 1),
#  (u'continued to search', 1),
#  (u'invited to deliver', 1),
#  (u'tried to reach', 1),
#  (u'professed to know', 1),
#  (u'obliged to become', 1),
#  (u'designed to put', 1),
#  (u'tended to emphasize', 1),
#  (u'wanted to identify', 1),
#  (u'designed to improve', 1),
#  (u'preferred to get', 1),
#  (u'tended to break', 1),
#  (u'serves to extend', 1),
#  (u'determined to keep', 1),
#  (u'chose to hit', 1),
#  (u'trying to acquire', 1),
#  (u'plan to travel', 1),
#  (u'began to involve', 1),
#  (u'neglect to cultivate', 1),
#  (u'want to lease', 1),
#  (u'trying to cut', 1),
#  (u'forced to go', 1),
#  (u'want to inquire', 1),
#  (u'striving to hold', 1),
#  (u'needed to hire', 1),
#  (u'Happened to hear', 1),
#  (u'expected to carry', 1),
#  (u'varied to allow', 1),
#  (u'threatened to form', 1),
#  (u'want to watch', 1),
#  (u'continued to threaten', 1),
#  (u'required to meet', 1),
#  (u'fails to pass', 1),
#  (u'close to emit', 1),
#  (u'started to buckle', 1),
#  (u'going to send', 1),
#  (u'plans to serve', 1),
#  (u'expects to tell', 1),
#  (u'try to swing', 1),
#  (u'reassuring to see', 1),
#  (u'com to sea', 1),
#  (u'strove to think', 1),
#  (u'directed to provide', 1),
#  (u'chooses to die', 1),
#  (u'determined to apply', 1),
#  (u'decided to capitalize', 1),
#  (u'like to organize', 1),
#  (u'refuse to mention', 1),
#  (u'propose to go', 1),
#  (u'allowed to account', 1),
#  (u'turned to add', 1),
#  (u'equipped to die', 1),
#  (u'leaping to light', 1),
#  (u'bound to go', 1),
#  (u'wanted to tell', 1),
#  (u'helping to further', 1),
#  (u'gone to get', 1),
#  (u'began to focus', 1),
#  (u'going to cost', 1),
#  (u'liked to fancy', 1),
#  (u'seem to vary', 1),
#  (u'trying to continue', 1),
#  (u'like to disclose', 1),
#  (u'sought to prevent', 1),
#  (u'wanted to clarify', 1),
#  (u'used to get', 1),
#  (u'seemed to mind', 1),
#  (u'helping to account', 1),
#  (u'seems to represent', 1),
#  (u'need to worry', 1),
#  (u'want to include', 1),
#  (u'continue to preach', 1),
#  (u'serves to crystallize', 1),
#  (u'trying to wreck', 1),
#  (u'helps to meet', 1),
#  (u'intend to include', 1),
#  (u'wants to go', 1),
#  (u'groped to reassemble', 1),
#  (u'seems to smell', 1),
#  (u'fail to take', 1),
#  (u'used to cut', 1),
#  (u'tried to insist', 1),
#  (u'hopes to visit', 1),
#  (u'began to converse', 1),
#  (u'promised to eat', 1),
#  (u'trying to outdo', 1),
#  (u'fail to show', 1),
#  (u'written to say', 1),
#  (u'directed to cover', 1),
#  (u'seems to thrust', 1),
#  (u'struggling to bridge', 1),
#  (u'interested to know', 1),
#  (u'liked to nip', 1),
#  (u'want to start', 1),
#  (u'going to wait', 1),
#  (u"goin' to kill", 1),
#  (u'told to purchase', 1),
#  (u'going to trouble', 1),
#  (u'going to set', 1),
#  (u'try to treat', 1),
#  (u'longing to fall', 1),
#  (u'prefers to designate', 1),
#  (u'beckoned to cross', 1),
#  (u'come to spend', 1),
#  (u'trained to read', 1),
#  (u'trying to clear', 1),
#  (u'selected to operate', 1),
#  (u'promised to pay', 1),
#  (u'seeming to like', 1),
#  (u'longed to increase', 1),
#  (u'turned to survey', 1),
#  (u'prepared to stay', 1),
#  (u'led to postulate', 1),
#  (u'came to favor', 1),
#  (u'equipped to care', 1),
#  (u'fail to bring', 1),
#  (u'obliged to roll', 1),
#  (u'need to make', 1),
#  (u'surprised to meet', 1),
#  (u'made to integrate', 1),
#  (u'interpreted to conform', 1),
#  (u'choose to call', 1),
#  (u'decided to migrate', 1),
#  (u'moving to create', 1),
#  (u'purport to advocate', 1),
#  (u'built to accommodate', 1),
#  (u'painted to match', 1),
#  (u'fail to give', 1),
#  (u'swung to see', 1),
#  (u'conscripted to enact', 1),
#  (u'proceeded to disturb', 1),
#  (u'trying to mollify', 1),
#  (u'beginning to discover', 1),
#  (u'used to derive', 1),
#  (u'thought to infest', 1),
#  (u'urged to attend', 1),
#  (u'managed to bat', 1),
#  (u'continue to provide', 1),
#  (u'tried to outface', 1),
#  (u'prepared to submit', 1),
#  (u'extended to provide', 1),
#  (u'needed to possess', 1),
#  (u'trying to touch', 1),
#  (u'trained to drag', 1),
#  (u'trying to follow', 1),
#  (u'intended to fill', 1),
#  (u'tried to compromise', 1),
#  (u'need to commit', 1),
#  (u'fails to meet', 1),
#  (u'seemed to focus', 1),
#  (u'helps to rebut', 1),
#  (u'used to frustrate', 1),
#  (u'ordered to retain', 1),
#  (u'began to ship', 1),
#  (u'expect to call', 1),
#  (u'twitching to dislodge', 1),
#  (u'try to end', 1),
#  (u'professing to believe', 1),
#  (u'began to shudder', 1),
#  (u'conditioned to expect', 1),
#  (u'acts to remove', 1),
#  (u'started to worry', 1),
#  (u'started to raise', 1),
#  (u'try to revive', 1),
#  (u'begun to falter', 1),
#  (u'come to understand', 1),
#  (u'seemed to mark', 1),
#  (u'voted to continue', 1),
#  (u'tending to arouse', 1),
#  (u'seem to add', 1),
#  (u'continued to help', 1),
#  (u'serve to sublimate', 1),
#  (u'continue to urge', 1),
#  (u'turned to jump', 1),
#  (u'tended to take', 1),
#  (u'chose to come', 1),
#  (u'begun to grow', 1),
#  (u'hopes to melt', 1),
#  (u'wish to congratulate', 1),
#  (u'needs to educate', 1),
#  (u'agreed to form', 1),
#  (u'mobilized to achieve', 1),
#  (u'begin to wither', 1),
#  (u'came to understand', 1),
#  (u'attempt to rise', 1),
#  (u'promise to make', 1),
#  (u'serves to stimulate', 1),
#  (u'taken to preserve', 1),
#  (u'generalized to include', 1),
#  (u'inclined to exaggerate', 1),
#  (u'allowed to warm', 1),
#  (u'forget to buy', 1),
#  (u'seems to know', 1),
#  (u'wanting to know', 1),
#  (u'cease to haunt', 1),
#  (u'get to hear', 1),
#  (u'trying to throw', 1),
#  (u'working to develop', 1),
#  (u'serve to promote', 1),
#  (u'planned to bolt', 1),
#  (u'combined to form', 1),
#  (u'hate to call', 1),
#  (u'begun to write', 1),
#  (u'intend to act', 1),
#  (u'tends to assert', 1),
#  (u'came to investigate', 1),
#  (u'hesitated to prosecute', 1),
#  (u'wished to call', 1),
#  (u'continued to accuse', 1),
#  (u'bothering to note', 1),
#  (u'determined to compel', 1),
#  (u'try to go', 1),
#  (u'wished to meet', 1),
#  (u'entitled to stay', 1),
#  (u'hired to repeat', 1),
#  (u'continue to abide', 1),
#  (u'got to drink', 1),
#  (u'startled to meet', 1),
#  (u'tried to roll', 1),
#  (u'descended to blot', 1),
#  (u'continues to take', 1),
#  (u'wish to note', 1),
#  (u'used to test', 1),
#  (u'waiting to catch', 1),
#  (u'continue to try', 1),
#  (u'love to visit', 1),
#  (u'learn to put', 1),
#  (u'failed to cooperate', 1),
#  (u'tried to force', 1),
#  (u'like to take', 1),
#  (u'going to leave', 1),
#  (u'sent to knoe', 1),
#  (u'crystallized to find', 1),
#  (u'allowed to preach', 1),
#  (u'tried to teach', 1),
#  (u'determined to hold', 1),
#  (u'go to look', 1),
#  (u'hesitate to ask', 1),
#  (u'going to louse', 1),
#  (u'paused to gather', 1),
#  (u'made to weave', 1),
#  (u'entitled to excoriate', 1),
#  (u'designed to enhance', 1),
#  (u'sought to place', 1),
#  (u'helped to deepen', 1),
#  (u'Asked to elaborate', 1),
#  (u'wanted to leave', 1),
#  (u'managed to swallow', 1),
#  (u'refused to move', 1),
#  (u'aimed to write', 1),
#  (u'attempting to extend', 1),
#  (u'used to construct', 1),
#  ...]
